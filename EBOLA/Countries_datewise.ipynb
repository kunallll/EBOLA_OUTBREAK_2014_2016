# %%
import pandas as pd 

df = pd.read_csv('ebola_2014_2016_clean.csv')

# %%
df
# Out:
#                        Country        Date  No. of suspected cases  \
# 0                       Guinea  2014-08-29                    25.0
# 1                      Nigeria  2014-08-29                     3.0
# 2                 Sierra Leone  2014-08-29                    54.0
# 3                      Liberia  2014-08-29                   382.0
# 4                 Sierra Leone  2014-09-05                    78.0
# ...                        ...         ...                     ...
# 2480                   Liberia  2016-03-23                  5636.0
# 2481                     Italy  2016-03-23                     0.0
# 2482                   Liberia  2016-03-23                     0.0
# 2483                   Nigeria  2016-03-23                     0.0
# 2484  United States of America  2016-03-23                     0.0
#
#       No. of probable cases  No. of confirmed cases  \
# 0                     141.0                   482.0
# 1                       1.0                    15.0
# ...

# %%
df['Country'].unique()
# Out:
# array(['Guinea', 'Nigeria', 'Sierra Leone', 'Liberia', 'Senegal',
#        'United States of America', 'Spain', 'Mali', 'United Kingdom',
#        'Italy'], dtype=object)

# %%
filt = (df['Country'] == 'Liberia')

# %%
filt = df['Country'] == 'Guinea'
import matplotlib.pyplot as plt1
import numpy as np

x_indexes = np.arange(df[filt]['Date'].count())
plt1.title('GUINEA')
plt1.xlabel('Days')
plt1.ylabel('Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of suspected cases'], label = 'Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of probable cases'], label = 'Probable Cases')
plt1.plot(x_indexes, df[filt]['No. of confirmed cases'], label = 'Confirmed Cases')
plt1.legend()

# %%
filt = df['Country'] == 'Sierra Leone'
import matplotlib.pyplot as plt1
import numpy as np

x_indexes = np.arange(df[filt]['Date'].count())
plt1.title('SIERRA LEONE')
plt1.xlabel('Days')
plt1.ylabel('Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of suspected cases'], label = 'Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of probable cases'], label = 'Probable Cases')
plt1.plot(x_indexes, df[filt]['No. of confirmed cases'], label = 'Confirmed Cases')
plt1.legend()

# %%
filt = df['Country'] == 'United States of America'
import matplotlib.pyplot as plt1
import numpy as np

x_indexes = np.arange(df[filt]['Date'].count())
plt1.title('UNITED STATES OF AMERICA')
plt1.xlabel('Days')
plt1.ylabel('Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of suspected cases'], label = 'Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of probable cases'], label = 'Probable Cases')
plt1.plot(x_indexes, df[filt]['No. of confirmed cases'], label = 'Confirmed Cases')
plt1.legend()

# %%
filt = df['Country'] == 'Nigeria'
import matplotlib.pyplot as plt1
import numpy as np

x_indexes = np.arange(df[filt]['Date'].count())
plt1.title('NIGERIA')
plt1.xlabel('Days')
plt1.ylabel('Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of suspected cases'], label = 'Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of probable cases'], label = 'Probable Cases')
plt1.plot(x_indexes, df[filt]['No. of confirmed cases'], label = 'Confirmed Cases')
plt1.legend()

# %%
filt = df['Country'] == 'Liberia'
import matplotlib.pyplot as plt1
import numpy as np

x_indexes = np.arange(df[filt]['Date'].count())
plt1.title('SPAIN')
plt1.xlabel('Days')
plt1.ylabel('Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of suspected cases'], label = 'Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of probable cases'], label = 'Probable Cases')
plt1.plot(x_indexes, df[filt]['No. of confirmed cases'], label = 'Confirmed Cases')
plt1.legend()

# %%
df[filt]['No. of suspected cases'].fillna(0.0, inplace = True)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df[filt][df['No. of suspected cases'] == 0]
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Country        Date  No. of suspected cases  No. of probable cases  \
# 2482  Liberia  2016-03-23                     0.0                    3.0
#
#       No. of confirmed cases  No. of confirmed, probable and suspected cases  \
# 2482                     2.0                                             5.0
#
#       No. of suspected deaths  No. of probable deaths  \
# 2482                      NaN                     3.0
#
#       No. of confirmed deaths  No. of confirmed, probable and suspected deaths
# 2482                      1.0                                              4.0

# %%
df.fillna(0.0, inplace = True)

# %%
df[filt]
# Out:
#       Country        Date  No. of suspected cases  No. of probable cases  \
# 3     Liberia  2014-08-29                   382.0                  674.0
# 6     Liberia  2014-09-05                   369.0                  888.0
# 12    Liberia  2014-09-08                   443.0                  969.0
# 17    Liberia  2014-09-12                   453.0                  974.0
# 23    Liberia  2014-09-16                   539.0                 1078.0
# ...       ...         ...                     ...                    ...
# 2465  Liberia  2015-12-29                  5636.0                 1879.0
# 2466  Liberia  2015-12-29                     0.0                    0.0
# 2479  Liberia  2016-03-23                     0.0                    0.0
# 2480  Liberia  2016-03-23                  5636.0                 1879.0
# 2482  Liberia  2016-03-23                     0.0                    3.0
#
#       No. of confirmed cases  No. of confirmed, probable and suspected cases  \
# ...

# %%
filt = df['Country'] == 'Liberia'
import matplotlib.pyplot as plt1
import numpy as np

plt.figure(figsize = (20,15))
x_indexes = np.arange(df[filt]['Date'].count())
plt1.xlabel('Days')
plt1.ylabel('Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of suspected cases'], label = 'Suspected Cases')
plt1.plot(x_indexes, df[filt]['No. of probable cases'], label = 'Probable Cases')
plt1.plot(x_indexes, df[filt]['No. of confirmed cases'], label = 'Confirmed Cases')
plt1.legend()
